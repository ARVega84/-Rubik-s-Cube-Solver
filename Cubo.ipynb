# %%
from ambiente import *
from busqueda import *

# %%
# %%time
# cubo = Cubo(estado_inicial=['arriba', 'arriba', 'arriba', 'arriba', 'frente', 'derecha', 'frente',
#                              'derecha', 'arriba', 'arriba', 'arriba', 'arriba', 'frente', 'derecha',
#                              'arriba', 'derecha', 'frente','arriba', 'derecha', 'arriba', 'derecha',
#                              'derecha', 'arriba', 'arriba', 'derecha', 'frente', 'arriba', 'derecha',
#                             'frente', 'frente'])
cubo = Cubo(movimientos=10)

cubo.pintar_estado(cubo.estado_inicial)
print(cubo.codigo(cubo.estado_inicial))



solucion_A_star = A_star(cubo)
camino_A_star = [cubo.estado_inicial] + solucion(solucion_A_star)
print('La solución mediante el algoritmo de primero en A_star es:')
print(camino_A_star)
print('El costo de la solución es:', solucion_A_star.costo_camino)
# Out:
# Movimientos realizados para mezclar el cubo: ['arriba', '!derecha', '!arriba', 'derecha', '!arriba', '!derecha', '!arriba', 'arriba', '!arriba', '!arriba']
# (4421)-(3011)-(4302)-(0332)-(5045)-(5125)
# La solución mediante el algoritmo de primero en A_star es:
# [[[4, 4, 2, 1], [3, 0, 1, 1], [4, 3, 0, 2], [0, 3, 3, 2], [5, 0, 4, 5], [5, 1, 2, 5]], 'arriba', 'arriba', 'derecha', 'arriba', '!derecha', 'arriba', 'derecha', '!arriba']
# El costo de la solución es: 8
# CPU times: user 420 ms, sys: 0 ns, total: 420 ms
# Wall time: 419 ms

# %%
# %%time
solucion_A_star = A_star(cubo)
camino_A_star = [cubo.estado_inicial] + solucion(solucion_A_star)
print('La solución mediante el algoritmo de primero en A_star es:')
print(camino_A_star)
print('El costo de la solución es:', solucion_A_star.costo_camino)
# Out:
# La solución mediante el algoritmo de primero en A_star es:
# [[[3, 3, 0, 0], [5, 3, 0, 1], [4, 4, 2, 2], [1, 0, 3, 5], [2, 2, 4, 4], [1, 1, 5, 5]], 'arriba', 'arriba', 'frente']
# El costo de la solución es: 3
# CPU times: user 12.4 ms, sys: 0 ns, total: 12.4 ms
# Wall time: 12.5 ms

# %%
# %%time
solucion_avara = avara(cubo)
camino_avara = [cubo.estado_inicial] + solucion(solucion_avara)
print('La solución mediante el algoritmo de primero en avara es:')
print(camino_avara)
print('El costo de la solución es:', solucion_avara.costo_camino)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in avara(problema)
#     225                 s = hijo.estado
#     226                 v = problema.heuristica(s)
# --> 227                 frontera.push(hijo, v)
#     228                 explorados.add(cod)
#     229
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in push(self, elemento, valor)
#     155         tupla = Tupla(elemento, valor)
#     156         self.pila.append(tupla)
# --> 157         self.pila.sort(key=lambda x: x[1])
#     158
#     159     def pop(self):
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in <lambda>(x)
#     155         tupla = Tupla(elemento, valor)
#     156         self.pila.append(tupla)
# --> 157         self.pila.sort(key=lambda x: x[1])
#     158
#     159     def pop(self):
#
# KeyboardInterrupt:

# %%
# %%time
solucion_dijkstra = dijkstra(cubo)
camino_dijkstra = [cubo.estado_inicial] + solucion(solucion_dijkstra)
print('La solución mediante el algoritmo de Dijkstra es:')
print(camino_dijkstra)
print('El costo de la solución es:', solucion_dijkstra.costo_camino)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in dijkstra(problema)
#     199             c = hijo.costo_camino
#     200             if cod not in explorados or c < explorados[cod]:
# --> 201                 frontera.push(hijo, c)
#     202                 explorados[cod] = c
#     203
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in push(self, elemento, valor)
#     155         tupla = Tupla(elemento, valor)
#     156         self.pila.append(tupla)
# --> 157         self.pila.sort(key=lambda x: x[1])
#     158
#     159     def pop(self):
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in <lambda>(x)
#     155         tupla = Tupla(elemento, valor)
#     156         self.pila.append(tupla)
# --> 157         self.pila.sort(key=lambda x: x[1])
#     158
#     159     def pop(self):
#
# KeyboardInterrupt:

# %%
# %%time
solucion_anchura = anchura(cubo)
camino_anchura = [cubo.estado_inicial] + solucion(solucion_anchura)
print('La solución mediante el algoritmo de primero en anchura es:')
print(camino_anchura)
print('El costo de la solución es:', solucion_anchura.costo_camino)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in anchura(problema)
#      70         acciones = problema.acciones_aplicables(nodo.estado)
#      71         for a in acciones:
# ---> 72             hijo = nodo_hijo(problema, nodo, a)
#      73             if problema.test_objetivo(hijo.estado):
#      74                 return hijo
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in nodo_hijo(problema, madre, accion)
#      22     # Output: nodo
#      23
# ---> 24     estado = problema.transicion(madre.estado, accion)
#      25     costo_camino = madre.costo_camino + problema.costo(madre.estado, accion)
#      26     codigo = problema.codigo(estado)
#
# ~/Desktop/IA/Proyecto2/Cubo/ambiente.py in transicion(self, estado, accion)
#     202                     "!derecha":self.giro_derecho_reves,
# ...

# %%
# %%time
solucion_profundidad = profundidad(cubo)
camino_profundidad = [cubo.estado_inicial] + solucion(solucion_profundidad)
print('La solución mediante el algoritmo de primero en profundidad es:')
print(camino_profundidad)
print('El costo de la solución es:', solucion_profundidad.costo_camino)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in profundidad(problema)
#      92             if problema.test_objetivo(hijo.estado):
#      93                 return hijo
# ---> 94             if not is_cycle(hijo):
#      95                 frontera.append(hijo)
#      96     return None
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in is_cycle(nodo)
#      46
#      47 def is_cycle(nodo):
# ---> 48     codigos = camino_codigos(nodo)
#      49     return len(set(codigos)) != len(codigos)
#      50
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in camino_codigos(nodo)
#      43         return [nodo.codigo]
#      44     else:
# ---> 45         return camino_codigos(nodo.madre) + [nodo.codigo]
#      46
#      47 def is_cycle(nodo):
#
# ~/Desktop/IA/Proyecto2/Cubo/busqueda.py in camino_codigos(nodo)
# ...

# %%
print(cubo.heuristica(cubo.estado_inicial))
# Out:
# 4
